# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

from cloudvolume import CloudVolume

# %%
precomputed_url = 'https://mousebrainatlas-datajoint-jp2k.s3.amazonaws.com/precomputed/MD585_fullres'

# %%
precomputed_vol = CloudVolume(precomputed_url)

# %%
cloud_img = precomputed_vol[200:700, 200:700, 40]
# Out:
# Downloading:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
img = np.squeeze(np.array(cloud_img))

# %%
plt.imshow(img, cmap="gray")
